# %%
getwd()
# Out:
# [1] "/home/hermuba/resistanceExp/EcoliGenomes/code/exp2_cdhit"

# %% [markdown]
# # require() and library()
# small piece of knowledge:
# [what is the difference between `require()` and `library()`](https://stackoverflow.com/questions/5595512/what-is-the-difference-between-require-and-library)
#
#
#
# There's not much of one in everyday work.
#
# However, according to the documentation for both functions (accessed by putting a ? before the function name and hitting enter), require is used inside functions, as it outputs a warning and continues if the package is not found, whereas library will throw an error.
#
# # installing r package: `conda -c r r-readxl`

# %%
# require is the import in python
#require(xlsx)
library(readxl)

# read the file
df <- read_excel("../../cdhitResult/cdhitPattern.xlsx")

# %%
head(df)
# Out:
#             Cluster 0 Cluster 1 Cluster 2 Cluster 3 Cluster 4 Cluster 5
# 1 1438681.3 1         0         0         0         0         0
# 2 1328432.3 1         0         1         0         0         0
# 3 1328434.3 1         0         0         0         0         0
# 4 1438688.3 1         0         0         0         0         0
# 5 1438693.3 1         1         0         1         1         0
# 6 1438694.3 1         1         0         0         1         0
#   Cluster 6 Cluster 7 Cluster 8 ⋯ Cluster 13551 Cluster 13552 Cluster 13553
# 1 0         0         1         ⋯ 1             0             0
# 2 0         0         1         ⋯ 0             0             0
# 3 0         0         1         ⋯ 0             0             0
# 4 0         0         1         ⋯ 0             0             0
# 5 0         0         0         ⋯ 0             0             0
# 6 0         0         0         ⋯ 0             0             0
# ...

# %%
# need to convert to matrix to plot heatmap
df_matrix <- data.matrix(df)

# %%
# there are two bugs, one is trace, the other is the interval of colors!! they took me an afternoon to fix them!!!!(Angry)
# heatmap.2 is taking forever :-(
library(gplots)
library(RColorBrewer)
hmcol = colorRampPalette(brewer.pal(9, "RdBu"))(100)
df_heatmap <- heatmap.2(df_matrix, dendrogram = "none", scale="none", trace = "none", col = hmcol, breaks = seq(-3, 3, length.out = 101))
# Out:
# Plot with title “Color Key
# and Histogram”
