# %%
import pandas as pd
df = pd.read_pickle("../../cdhitResult/ec0913_df")
cluster_detail = pd.read_pickle("../../cdhitResult/cluster_detail_df")
ris = pd.read_pickle("../../../data/anno_sps_df")

# %%
df.head()
# Out:
#            Cluster 0  Cluster 1  Cluster 2  Cluster 3  Cluster 4  Cluster 5  \
# 1438693.3       True       True      False       True       True      False
# 1438681.3       True      False      False      False      False      False
# 1328432.3       True      False       True      False      False      False
# 1438694.3       True       True      False      False       True      False
# 1328434.3       True      False      False      False      False      False
#
#            Cluster 6  Cluster 7  Cluster 8  Cluster 9      ...        \
# 1438693.3      False      False      False      False      ...
# 1438681.3      False      False      False       True      ...
# 1328432.3      False      False      False       True      ...
# 1438694.3      False      False      False      False      ...
# 1328434.3      False      False      False       True      ...
#
#            Cluster 15940  Cluster 15941  Cluster 15942  Cluster 15943  \
# 1438693.3          False          False          False          False
# 1438681.3          False          False          False          False
# 1328432.3          False          False          False          False
# 1438694.3          False          False          False          False
# 1328434.3          False          False          False          False
#
#            Cluster 15944  Cluster 15945  Cluster 15946  Cluster 15947  \
# 1438693.3          False          False          False          False
# 1438681.3          False          False          False          False
# 1328432.3          False          False          False          False
# 1438694.3          False          False          False          False
# 1328434.3          False          False          False          False
#
#            Cluster 15948  Cluster 15949
# 1438693.3          False          False
# 1438681.3          False          False
# 1328432.3          False          False
# 1438694.3          False          False
# 1328434.3          False           True
#
# [5 rows x 15950 columns]

# %% [markdown]
# # total gene

# %%
# core genome, accessory genome
gene_count = df.sum(axis = 0)
core = gene_count.loc[gene_count == 59] 
accessory = gene_count.loc[gene_count != 59]
unique = gene_count.loc[gene_count == 1]

# %%
print(len(core), len(accessory), len(unique))
# Out:
# 2874 13076 5522

# %%
# determine how conserved they are: they are all similar
core_sim = cluster_detail.loc[core.index.values, 'mean similarity'].mean()
acc_sim = cluster_detail.loc[accessory.index.values, 'mean similarity'].mean()
print(core_sim, acc_sim)
# Out:
# 99.4795391609 99.6570323545

# %%
# determine the length gap between representing sequence and other members of the family
core_len_gap_se = cluster_detail.loc[core.index.values, 'representing gene length'] - cluster_detail.loc[core.index.values, 'mean length']
accessory_len_gap_se = cluster_detail.loc[accessory.index.values, 'representing gene length'] - cluster_detail.loc[accessory.index.values, 'mean length']
print(core_len_gap_se.mean(), accessory_len_gap_se.mean())
# Out:
# 329.137976 206.474566834

# %% [markdown]
# # stratified by phenotype

# %%
ris_need = ris[["Genome ID", "Resistant Phenotype", "Antibiotic"]]
df_ris = pd.merge(df, ris_need, left_index = True, right_on = "Genome ID")

# %%
# data abundance
count = df_ris[["Cluster 0", "Antibiotic"]].groupby(by = "Antibiotic").count()
count.sort_values(by = "Cluster 0")
# Out:
#                                Cluster 0
# Antibiotic
# tylosin                                0
# clindamycin                            0
# sulfadimethoxine                       0
# enrofloxacin                           0
# florfenicol                            0
# tulathromycin                          0
# kanamycin                              0
# tiamulin                               0
# moxifloxacin                           0
# nalidixic acid                         0
# neomycin                               0
# oxytetracycline                        0
# penicillin                             0
# sulphonamides                          0
# spectinomycin                          0
# streptomycin                           0
# ticarcillin                            0
# chlortetracycline                      0
# danofloxacin                           0
# sulfisoxazole                          0
# timentin                               0
# ceftiofur                              0
# ceftazidime/clavulanic acid            0
# azithromycin                           0
# ticarcillin/clavulanic acid            0
# carbapenem                             0
# tilmicosin                             0
# cefoperazone/sulbactam                 0
# cefotetan                              0
# cefuroxime                             0
# ...                                  ...
# chloramphenicol                        1
# minocycline                            6
# polymyxin B                            6
# doxycycline                            6
# doripenem                              7
# amoxicillin/clavulanic acid            8
# aztreonam                             10
# colistin                              12
# cephalothin                           14
# tetracycline                          15
# cefoxitin                             20
# cefotaxime                            21
# levofloxacin                          21
# ertapenem                             23
# tigecycline                           24
# imipenem                              24
# amikacin                              27
# nitrofurantoin                        28
# ceftriaxone                           33
# tobramycin                            33
# piperacillin/tazobactam               33
# cefepime                              39
# ceftazidime                           46
# ampicillin/sulbactam                  46
# cefazolin                             47
# ampicillin                            47
# trimethoprim/sulfamethoxazole         47
# ciprofloxacin                         49
# gentamicin                            49
# meropenem                             58
#
# [67 rows x 1 columns]

# %%
# import
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
mpl.style.use('ggplot')
# %matplotlib inline

# %%
# cog for cdhit
cluster_detail = pd.read_pickle("../../cdhitResult/cluster_detail_df")
cog = pd.read_pickle("../../cdhitResult/ec_core_cog_df")
card = pd.read_pickle("../../cdhitResult/ec0913_card_df")
cog_detail = pd.merge(cluster_detail, cog, left_on = "representing gene header", right_index = True)
card_detail = pd.merge(card, cluster_detail, right_on = "representing gene header", left_index = True, how = 'outer')


card_yn = pd.DataFrame()
card_yn = card_yn.append(card_detail['ARO'].notnull())

# %%
plt.figure(figsize = (40,5))
plt.pcolor(card_yn)

# %%
# input antibiotic
# output: core gene size, accessory gene size
def stra_by_abx(abx):
    abx_choose = df_ris.loc[df_ris['Antibiotic'] == abx]
    
    freq = abx_choose.groupby(by = "Resistant Phenotype").mean() #frequency == 1: core genome
    freq_only_cluster = freq.iloc[:, 0:15949]
    freq_only_cluster = freq_only_cluster.loc[freq_only_cluster['Cluster 1'].notnull()]
    
    ratio = freq_only_cluster.loc['Resistant', :]/freq_only_cluster.loc['Susceptible', :]
    i = ratio.sort_values().index

    
    sort = abx_choose.sort_values("Resistant Phenotype")
    only_cluster = sort.iloc[:,0:15949]
    
    
    
    plt.figure(figsize = (40,6))
    #absense presence pattern
    plt.subplot(3, 1, 1)
    sort_by_ratio = only_cluster[i]
    plt.pcolor(sort_by_ratio)
    plt.yticks(np.arange(0.5, len(sort.index), 1), sort["Resistant Phenotype"])
    plt.xticks(np.arange(0.5, len(sort_by_ratio.columns), 1), sort_by_ratio.columns)
    plt.title(abx + ' absence presence pattern')
    
    #frequency map 
    plt.subplot(3, 1, 2)
    sort_by_ratio = freq_only_cluster[i]
    plt.pcolor(sort_by_ratio)
    plt.yticks(np.arange(0.5, len(freq_only_cluster.index), 1), freq_only_cluster.index)
    plt.xticks(np.arange(0.5, len(sort_by_ratio.columns), 1), sort_by_ratio.columns)
    plt.title(abx + ' frequency map') 
    
    # card yes or no
    plt.subplot(3,1,3)
    sort_by_ratio = card_yn[i]
    plt.pcolor(sort_by_ratio)
    plt.ylabel('CARD annotation')
    
    plt.show()

# %%
stra_by_abx("meropenem")

# %% [markdown]
# pattern not prominent, why?
# 1. these rare genes are Noise?
# 2. because CARD annotation include all annotation, stratify with "determinant of": meropenem
# 3. blast all cog to see what they are?
# 4. problem with cdhit not being about to see snp-level variance?

# %%
stra_by_abx("imipenem")

# %%
stra_by_abx("gentamicin")

# %%
stra_by_abx("ciprofloxacin")

# %%
cluster_detail.head()
# Out:
#           representing gene length    representing gene header  \
# Cluster 0                     6925  JMVJ01000010_255|1438681.3
# Cluster 1                     5901  JMVT01000001_309|1438693.3
# Cluster 2                     5423  AYIO01000007_135|1328432.3
# Cluster 3                     3903   JAPE01000016_72|1400157.3
# Cluster 4                     3709  JMVU01000017_403|1438694.3
#
#           mean similarity mean length
# Cluster 0          98.031     329.762
# Cluster 1             100       983.5
# Cluster 2             100      2711.5
# Cluster 3         99.2221     89.0714
# Cluster 4          99.208       370.9

# %%
card.head()
# Out:
#                                     ARO  \
# JMUY01000005_592|1438670.3  ARO:3001328
# JMUY01000002_298|1438670.3  ARO:3000516
# JMUY01000004_240|1438670.3  ARO:3000795
# JMUY01000006_99|1438670.3   ARO:3003550
# JMUY01000003_100|1438670.3  ARO:3003308
#
#                                                                      ARO_name  \
# JMUY01000005_592|1438670.3                                               MdfA
# JMUY01000002_298|1438670.3                                               emrR
# JMUY01000004_240|1438670.3                                               mdtE
# JMUY01000006_99|1438670.3                                                mdtP
# JMUY01000003_100|1438670.3  Escherichia coli parC conferring resistance to...
#
#                                                                     ARO_group  \
# JMUY01000005_592|1438670.3  efflux pump complex or subunit conferring anti...
# JMUY01000002_298|1438670.3  efflux pump complex or subunit conferring anti...
# JMUY01000004_240|1438670.3  efflux pump complex or subunit conferring anti...
# JMUY01000006_99|1438670.3   efflux pump complex or subunit conferring anti...
# JMUY01000003_100|1438670.3  antibiotic resistant gene variant or mutant; d...
#
#                              snp cut_off
# JMUY01000005_592|1438670.3   n/a  Strict
# JMUY01000002_298|1438670.3   n/a  Strict
# JMUY01000004_240|1438670.3   n/a  Strict
# JMUY01000006_99|1438670.3    n/a  Strict
# JMUY01000003_100|1438670.3  S80I  Strict

# %%
cog.head()
# Out:
#                               cog_ID cog_category
# JMUY01000001_5|1438670.3     COG5301            S
# JMUY01000001_1111|1438670.3  COG5301            S
# JMUY01000001_6|1438670.3     COG4385            R
# JMUY01000001_68|1438670.3    COG4385            R
# JMUY01000001_1112|1438670.3  COG4385            R

# %%
core.index
# Out:
# Index(['Cluster 55', 'Cluster 72', 'Cluster 83', 'Cluster 90', 'Cluster 115',
#        'Cluster 140', 'Cluster 142', 'Cluster 145', 'Cluster 150',
#        'Cluster 153',
#        ...
#        'Cluster 15595', 'Cluster 15619', 'Cluster 15621', 'Cluster 15691',
#        'Cluster 15716', 'Cluster 15771', 'Cluster 15774', 'Cluster 15828',
#        'Cluster 15859', 'Cluster 15904'],
#       dtype='object', length=2874)

# %%
cog_detail.shape
# Out:
# (3613, 6)

# %%
cluster_detail.shape
# Out:
# Cluster 15923         JJMX01000035_12|1445863.3             100         5.8
# Cluster 15924          JJMX01000099_1|1445863.3             100        14.5
# Cluster 15925         JMUZ01000016_27|1438671.3             100           1
# Cluster 15926         AYHT01000011_89|1328450.3             100       3.625
# Cluster 15927          AYIO01000019_4|1328432.3             100        14.5
# Cluster 15928         JAPR01000021_13|1328434.3             100        14.5
# Cluster 15929         JMVV01000003_85|1438695.3             100        14.5
# Cluster 15930        JMVQ01000008_330|1438688.3             100        14.5
# Cluster 15931        JMVQ01000038_197|1438688.3             100        14.5
# Cluster 15932          MJAL01000004_9|562.13502             100         5.8
# Cluster 15933          MJAL01000039_3|562.13502             100        14.5
# Cluster 15934          JMVJ01000045_1|1438681.3             100          14
# Cluster 15935          JMVG01000024_1|1438678.3             100        13.5
# Cluster 15936         JJMY01000015_99|1445862.3             100     4.33333
# Cluster 15937          JMUW01000009_1|1438668.3             100          13
# Cluster 15938         JJMX01000037_21|1445863.3             100          13
# Cluster 15939          AYIO01000041_2|1328432.3             100          13
# Cluster 15940        JMVQ01000012_145|1438688.3             100          13
# Cluster 15941          JJMY01000035_1|1445862.3             100     3.57143
# Cluster 15942          MPCP01000004_1|562.12959             100        12.5
# Cluster 15943          JJMX01000015_1|1445863.3             100         4.8
# Cluster 15944          MJAL01000005_1|562.13502             100        11.5
# Cluster 15945          MJAL01000023_1|562.13502             100          11
# Cluster 15946          MJAL01000069_1|562.13502             100          11
# Cluster 15947          JMVP01000050_1|1438687.3             100        10.5
# Cluster 15948         JJMX01000040_21|1445863.3             100           4
# Cluster 15949        JAPR01000007_802|1328434.3             100          10
#
# [15843 rows x 9 columns]

# %%
card_detail['ARO'].notnull()
# Out:
# Cluster 2995     False
# Cluster 9305     False
# Cluster 3451     False
# Cluster 1961     False
# Cluster 754      False
# Cluster 1511     False
# Cluster 2464     False
# Cluster 936      False
# Cluster 3412     False
# Cluster 10980    False
# Cluster 5687     False
# Cluster 3283     False
# Cluster 5700     False
# Cluster 3221     False
# Cluster 1513     False
# Cluster 2965     False
# Cluster 297      False
# Cluster 3361     False
# Cluster 1564     False
# Cluster 1017     False
# Cluster 3344     False
# Cluster 6441     False
# Cluster 3397     False
# Cluster 8328     False
# Cluster 1731     False
# Cluster 8029     False
# Cluster 10952    False
# Cluster 10979    False
# Cluster 4971     False
# Cluster 4772     False
#                  ...
# Cluster 15920     True
# Cluster 15921     True
# Cluster 15922     True
# Cluster 15923     True
# Cluster 15924     True
# Cluster 15925     True
# Cluster 15926     True
# Cluster 15927     True
# Cluster 15928     True
# Cluster 15929     True
# Cluster 15930     True
# Cluster 15931     True
# Cluster 15932     True
# Cluster 15933     True
# Cluster 15934     True
# Cluster 15935     True
# Cluster 15936     True
# Cluster 15937     True
# Cluster 15938     True
# Cluster 15939     True
# Cluster 15940     True
# Cluster 15941     True
# Cluster 15942     True
# Cluster 15943     True
# Cluster 15944     True
# Cluster 15945     True
# Cluster 15946     True
# Cluster 15947     True
# Cluster 15948     True
# Cluster 15949     True
# Name: ARO, Length: 15950, dtype: bool
