# %%
# ris dataframe
import pandas as pd
ris = pd.read_pickle("../../../data/anno_sps_df")
ris_need = ris[['Genome ID', 'Antibiotic', 'Resistant Phenotype', 'Measurement Value', 'Species']]

# %%
ris_need.head()
# Out:
#    Genome ID                   Antibiotic Resistant Phenotype  \
# 0  1438670.3                  ceftriaxone           Resistant
# 1  1438776.3                    ertapenem           Resistant
# 2   573.9724  amoxicillin/clavulanic acid           Resistant
# 3  1400157.3                     imipenem        Intermediate
# 4  72407.183      piperacillin/tazobactam     Non-susceptible
#
#   Measurement Value      Species
# 0                32  Escherichia
# 1               nan   Klebsiella
# 2             32/16   Klebsiella
# 3                 2  Escherichia
# 4              64/4   Klebsiella

# %%
ris_need.loc[ris_need["Resistant Phenotype"].isnull()]
# Out:
#        Genome ID                     Antibiotic Resistant Phenotype  \
# 11     1400151.3                    tigecycline                 NaN
# 34     1438696.3                    cephalothin                 NaN
# 58     1400178.3                    tigecycline                 NaN
# 113    1400178.3                    cephalothin                 NaN
# 122    1329853.3                    tigecycline                 NaN
# 133    72407.234                    polymyxin B                 NaN
# 144    1328377.3                    cephalothin                 NaN
# 174    72407.189    ticarcillin/clavulanic acid                 NaN
# 183    1328370.3                    cephalothin                 NaN
# 197    72407.178                    tigecycline                 NaN
# 216    1438794.3                    cephalothin                 NaN
# 240    1328393.3                    tigecycline                 NaN
# 257    72407.153                    tigecycline                 NaN
# 266    72407.236                    polymyxin B                 NaN
# 271    1438796.3                    cephalothin                 NaN
# 311    1438808.3                    tigecycline                 NaN
# 326    72407.175                    tigecycline                 NaN
# 355    1329852.3                    tigecycline                 NaN
# 356    1400173.3                    cephalothin                 NaN
# 371    1400181.3                    tigecycline                 NaN
# 393    72407.242                    polymyxin B                 NaN
# 418    72407.192    ticarcillin/clavulanic acid                 NaN
# 422    72407.175    ticarcillin/clavulanic acid                 NaN
# 425    1438791.3                    cephalothin                 NaN
# 432    1438790.3                    tigecycline                 NaN
# 442    72407.168    ticarcillin/clavulanic acid                 NaN
# 456    72407.239    ticarcillin/clavulanic acid                 NaN
# 458    1400143.3                    cephalothin                 NaN
# 474    72407.240    ticarcillin/clavulanic acid                 NaN
# 475    1400137.3                    cephalothin                 NaN
# ...          ...                            ...                 ...
# 16751   76759.14                     tilmicosin                 NaN
# 16773    47885.7              chlortetracycline                 NaN
# 16774    47885.7                   enrofloxacin                 NaN
# 16796   287.2980  trimethoprim/sulfamethoxazole                 NaN
# 16864   287.2977                      ertapenem                 NaN
# 16910    47885.7                     ampicillin                 NaN
# 16924   287.2563                     tilmicosin                 NaN
# 16997   287.2980                      cefazolin                 NaN
# 17002   287.2979                     ampicillin                 NaN
# 17008   76759.14                oxytetracycline                 NaN
# 17011   287.2563               sulfadimethoxine                 NaN
# 17045   287.2979                    ceftriaxone                 NaN
# 17050   76759.14                    clindamycin                 NaN
# 17063   287.2974                      cefazolin                 NaN
# 17087   287.2976                   tetracycline                 NaN
# 17089   287.2975                    ceftriaxone                 NaN
# 17093   287.2980           ampicillin/sulbactam                 NaN
# 17094   287.2980                    tigecycline                 NaN
# 17110   287.2976           ampicillin/sulbactam                 NaN
# 17120   287.2978                     cefotaxime                 NaN
# 17133   76759.14                   enrofloxacin                 NaN
# 17182   287.2976    amoxicillin/clavulanic acid                 NaN
# 17189   287.2977    amoxicillin/clavulanic acid                 NaN
# 17226   287.2977           ampicillin/sulbactam                 NaN
# 17253   76759.14                       neomycin                 NaN
# 17291   287.2974                   tetracycline                 NaN
# 17293   287.2563                     ampicillin                 NaN
# 17297   287.2980                   tetracycline                 NaN
# 17318   287.2979                      ertapenem                 NaN
# 17350    47885.7                oxytetracycline                 NaN
#
#       Measurement Value                 Species
# 11                    8            Enterobacter
# 34                    1             Escherichia
# 58                    2              Klebsiella
# 113                  16              Klebsiella
# 122                   2            Enterobacter
# 133                   1              Klebsiella
# 144                   8              Klebsiella
# 174               128/2              Klebsiella
# 183                   1              Klebsiella
# 197                   1              Klebsiella
# 216                  64              Klebsiella
# 240                   2              Klebsiella
# 257                   2              Klebsiella
# 266                   1              Klebsiella
# 271                   2              Klebsiella
# 311                   4              Klebsiella
# 326                   1              Klebsiella
# 355                   2            Enterobacter
# 356                   1              Klebsiella
# 371                   2              Klebsiella
# 393                   1              Klebsiella
# 418                64/2              Klebsiella
# 422               128/2              Klebsiella
# 425                   1              Klebsiella
# 432                   2              Klebsiella
# 442               128/2              Klebsiella
# 456               128/2              Klebsiella
# 458                   1            Enterobacter
# 474               128/2              Klebsiella
# 475                   1             Citrobacter
# ...                 ...                     ...
# 16751                64  Pseudomonas aeruginosa
# 16773                 1  Pseudomonas aeruginosa
# 16774              0.25  Pseudomonas aeruginosa
# 16796             8/152  Pseudomonas aeruginosa
# 16864                 8  Pseudomonas aeruginosa
# 16910                 8  Pseudomonas aeruginosa
# 16924                64  Pseudomonas aeruginosa
# 16997                 8  Pseudomonas aeruginosa
# 17002                32  Pseudomonas aeruginosa
# 17008                 1  Pseudomonas aeruginosa
# 17011               256  Pseudomonas aeruginosa
# 17045                32  Pseudomonas aeruginosa
# 17050                16  Pseudomonas aeruginosa
# 17063                 8  Pseudomonas aeruginosa
# 17087                32  Pseudomonas aeruginosa
# 17089                32  Pseudomonas aeruginosa
# 17093             32/16  Pseudomonas aeruginosa
# 17094                 4  Pseudomonas aeruginosa
# 17110             32/16  Pseudomonas aeruginosa
# 17120                64  Pseudomonas aeruginosa
# 17133               0.5  Pseudomonas aeruginosa
# 17182             32/16  Pseudomonas aeruginosa
# 17189             32/16  Pseudomonas aeruginosa
# 17226             32/16  Pseudomonas aeruginosa
# 17253                 4  Pseudomonas aeruginosa
# 17291                16  Pseudomonas aeruginosa
# 17293                16  Pseudomonas aeruginosa
# 17297                32  Pseudomonas aeruginosa
# 17318                 8  Pseudomonas aeruginosa
# 17350               0.5  Pseudomonas aeruginosa
#
# [895 rows x 5 columns]

# %%
# classification tool
clsi = pd.read_excel("../../../data/CLSI_m100_breakpoint.xlsx")
category = clsi[['category', 'drug']]
category = category.drop_duplicates(subset = 'drug')

# %%
order = ['penicillins', 'b_lactam_inhibitor', 'cephems', 'monobactams', 'carbapenems', 'lipopeptides', 'phenicols', 'macrolides', 'aminoglycosides', 'tetracyclines', 'quinolones', 'folate_path','nitrofurans', 'fosfomycins']

# %%
for i in order:
    category.loc[category['category'] == i,'order'] = order.index(i) 
category
# Out:
#               category                           drug  order
# 0          nitrofurans                 nitrofurantoin   12.0
# 1           quinolones                  ciprofloxacin   10.0
# 2           quinolones                   levofloxacin   10.0
# 3           quinolones                      ofloxacin   10.0
# 4          folate_path  trimethoprim/sulfamethoxazole   11.0
# 5          folate_path                   sulfonamides   11.0
# 6          folate_path                   trimethoprim   11.0
# 7            phenicols                chloramphenicol    6.0
# 8          fosfomycins                     fosfomycin   13.0
# 9      aminoglycosides                     netilmicin    8.0
# 10          macrolides                   azithromycin    7.0
# 11       tetracyclines                   tetracycline    9.0
# 12       tetracyclines                    doxycycline    9.0
# 13       tetracyclines                    minocycline    9.0
# 16          quinolones                      cinoxacin   10.0
# 17          quinolones                       enoxacin   10.0
# 18          quinolones                   gatifloxacin   10.0
# 19          quinolones                   gemifloxacin   10.0
# 20          quinolones                  grepafloxacin   10.0
# 21          quinolones                   lomefloxacin   10.0
# 22          quinolones                 nalidixic acid   10.0
# 23          quinolones                    norfloxacin   10.0
# 24          quinolones                     olfloxacin   10.0
# 25          quinolones                     fleroxacin   10.0
# 26         monobactams                      aztreonam    3.0
# 27         carbapenems                      doripenem    4.0
# 28         carbapenems                      ertapenem    4.0
# 29         carbapenems                       imipenem    4.0
# 30         carbapenems                      meropenem    4.0
# 31     aminoglycosides                     gentamicin    8.0
# ..                 ...                            ...    ...
# 42             cephems                       cefaclor    2.0
# 43             cephems                       cefdinir    2.0
# 44             cephems                       cefixime    2.0
# 45             cephems                    cefpodoxime    2.0
# 46             cephems                      cefprozil    2.0
# 47             cephems                      cefatamet    2.0
# 48             cephems                     ceftibuten    2.0
# 50             cephems                    ceftaroline    2.0
# 51             cephems                       cefepime    2.0
# 52             cephems                     cefotaxime    2.0
# 53             cephems                    ceftriaxone    2.0
# 54             cephems                      cefotetan    2.0
# 55             cephems                      cefoxitin    2.0
# 57             cephems                    ceftazidime    2.0
# 58             cephems                    cefamandole    2.0
# 59             cephems                    cefmatazole    2.0
# 60         penicillins                     ampicillin    0.0
# 61         penicillins                   piperacillin    0.0
# 62         penicillins                     mecillinam    0.0
# 63  b_lactam_inhibitor    amoxicillin/clavulanic acid    1.0
# 64  b_lactam_inhibitor           ampicillin/sulbactam    1.0
# 65  b_lactam_inhibitor         ceftolozane/tazobactam    1.0
# 66  b_lactam_inhibitor        piperacillin/tazobactam    1.0
# 67  b_lactam_inhibitor          ticarcillin/clavunate    1.0
# 71        lipopeptides                       colistin    5.0
# 82         penicillins                    pipercillin    0.0
# 83  b_lactam_inhibitor        piperacillin-tazobactam    1.0
# 84  b_lactam_inhibitor         ceftolozane-tazobactam    1.0
# 85  b_lactam_inhibitor          ticarcillin-clavunate    1.0
# 93        lipopeptides                    polymyxin B    5.0
#
# [70 rows x 3 columns]

# %%
# generate antibiotic v.s. genome distribution matrix
genome = ris_need['Genome ID'].unique()
abx = ris_need['Antibiotic'].unique()
matrix = pd.DataFrame(columns = abx, index = genome, dtype = float)

# level of resistance to number
level = {'Resistant': 5,
        'Non-susceptible' : 4,
        'Intermediate': 3,
        'Not defined': 2,
        'Susceptible': 1}
for index, row in ris_need.iterrows():
    if row['Resistant Phenotype'] in list(level.keys()):
        matrix.loc[row['Genome ID'], row['Antibiotic']] = level[row['Resistant Phenotype']]

# %%
# sort against category of drug
category_subset = category.loc[category['drug'].isin(abx)]
sorted_drug = category_subset.sort_values('order')['drug']

# %%
# sorted matrix
sub_matrix = matrix[sorted_drug]
sub_matrix = sub_matrix.sort_values("gentamicin")
m = sub_matrix.as_matrix()
# -10 for nan

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
mpl.style.use("ggplot")
# plot inline
# %matplotlib inline

plt.figure(figsize = (10,30))
m = np.ma.masked_where(np.isnan(m),m)
plt.pcolor(m, cmap='rainbow', vmin=1, vmax=5)
plt.xticks(np.arange(0.5, len(sub_matrix.columns), 1), sub_matrix.columns, rotation = 90)
plt.colorbar(orientation='horizontal')
plt.show()
# Out:
# /home/hermuba/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize = (15,15))
plt.matshow(sub_matrix.corr(), cmap = 'rainbow', fignum=1)
plt.xticks(np.arange(0, len(sub_matrix.columns), 1), sub_matrix.columns, rotation = 90)
plt.yticks(np.arange(0, len(sub_matrix.columns), 1), sub_matrix.columns)
plt.colorbar(orientation='horizontal')
plt.show()
# Out:
# /home/hermuba/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Out:
# array(['1438670.3', '1400157.3', '1328443.3', '1438693.3', '1438673.3',
#        '1438677.3', '1445862.3', '1438696.3', '562.10576', '1438678.3',
#        '562.12959', '1438681.3', '1400158.3', '1438668.3', '562.12960',
#        '562.16325', '1445863.3', '562.16327', '562.16326', '1328448.3',
#        '1438691.3', '1438687.3', '1438671.3', '1328446.3', '1328450.3',
#        '1328432.3', '562.16466', '1438686.3', '1438682.3', '1438680.3',
#        '1438694.3', '1328434.3', '1438695.3', '562.16324', '1438676.3',
#        '1400156.3', '1328439.3', '1438679.3', '1328437.3', '1328449.3',
#        '1438674.3', '1438669.3', '1438689.3', '1328442.3', '1438685.3',
#        '1438672.3', '1438684.3', '1438688.3', '1328433.3', '1438683.3',
#        '1438675.3', '1328440.3', '1328441.3', '1328445.3', '1328447.3',
#        '1328438.3', '562.13502', '1328444.3', '1328436.3'], dtype=object)

# %%
ec = sub_matrix.loc[ris_need.loc[ris_need['Species'] == 'Escherichia']['Genome ID'].unique()]
ec = ec.sort_values("gentamicin")
m = ec.as_matrix()

plt.figure(figsize = (10,20))
m = np.ma.masked_where(np.isnan(m),m)
plt.pcolor(m, cmap='rainbow', vmin=1, vmax=5)
plt.xticks(np.arange(0.5, len(ec.columns), 1), ec.columns, rotation = 90)
plt.colorbar(orientation='horizontal')
plt.show()
# Out:
# /home/hermuba/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize = (15,15))
plt.matshow(ec.corr(), cmap = 'rainbow', fignum=1)
plt.xticks(np.arange(0, len(ec.columns), 1), ec.columns, rotation = 90)
plt.yticks(np.arange(0, len(ec.columns), 1), ec.columns)
plt.colorbar(orientation='horizontal')
plt.show()
# Out:
# /home/hermuba/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
